# %%
# !git clone https://github.com/kuba-szostak/TADLWP
# Out:
# fatal: destination path 'TADLWP' already exists and is not an empty directory.

# %%
# %ls
# Out:
# pycharm-libs/  sample_data/  TADLWP/

# %%
# %cd TADLWP
# Out:
# /content/TADLWP

# %%
# %cd Lab6_student/student/code
# Out:
# /content/TADLWP/Lab6_student/student/code

# %%
import part_1 as p1
p1.main()
# Out:
# Loading CIFAR-10 dataset...
# Dataset loaded
# GPU available: Tesla T4
# Epoch 1/8 - Train Loss: 2.3101, Train Acc: 0.0710 - Val Loss: 2.3037, Val Acc: 0.1094
# Epoch 2/8 - Train Loss: 2.3057, Train Acc: 0.1020 - Val Loss: 2.3031, Val Acc: 0.1002
# Epoch 3/8 - Train Loss: 2.3018, Train Acc: 0.1110 - Val Loss: 2.3034, Val Acc: 0.0960
# Epoch 4/8 - Train Loss: 2.2991, Train Acc: 0.1110 - Val Loss: 2.3039, Val Acc: 0.0974
# Epoch 5/8 - Train Loss: 2.2970, Train Acc: 0.1080 - Val Loss: 2.3048, Val Acc: 0.0992
# Epoch 6/8 - Train Loss: 2.2959, Train Acc: 0.1160 - Val Loss: 2.3060, Val Acc: 0.1004
# Epoch 7/8 - Train Loss: 2.2948, Train Acc: 0.1230 - Val Loss: 2.3068, Val Acc: 0.1100
# Epoch 8/8 - Train Loss: 2.2938, Train Acc: 0.1310 - Val Loss: 2.3073, Val Acc: 0.1178
# ...
# FX GRAPH NODES
# ...
# name=x                    op=placeholder     target=x
# name=net_0_net_0          op=call_module     target=net.0.net.0
# name=net_0_net_1          op=call_module     target=net.0.net.1
# ...

# %%
# !git pull
# Out:
# Already up to date.

# %%
import part_2 as p2
p2.main()
# Out:
# Loading CIFAR-10 dataset...
# Dataset loaded
# GPU available: Tesla T4
# Epoch 1/8 - Train Loss: 2.3057, Train Acc: 0.0920 - Val Loss: 2.2996, Val Acc: 0.1452
# Epoch 2/8 - Train Loss: 2.2958, Train Acc: 0.1410 - Val Loss: 2.2963, Val Acc: 0.1096
# Epoch 3/8 - Train Loss: 2.2863, Train Acc: 0.1360 - Val Loss: 2.2847, Val Acc: 0.1164
# Epoch 4/8 - Train Loss: 2.2732, Train Acc: 0.1690 - Val Loss: 2.2639, Val Acc: 0.1604
# Epoch 5/8 - Train Loss: 2.2447, Train Acc: 0.1800 - Val Loss: 2.2264, Val Acc: 0.1630
# Epoch 6/8 - Train Loss: 2.2112, Train Acc: 0.1630 - Val Loss: 2.1825, Val Acc: 0.1608
# Epoch 7/8 - Train Loss: 2.1554, Train Acc: 0.1890 - Val Loss: 2.1199, Val Acc: 0.1828
# Epoch 8/8 - Train Loss: 2.1485, Train Acc: 0.1790 - Val Loss: 2.1525, Val Acc: 0.1794
# ...
# FX GRAPH NODES
# ...
# name=x                    op=placeholder     target=x
# name=net_0_net_0          op=call_module     target=net.0.net.0
# name=net_0_net_1          op=call_module     target=net.0.net.1
# ...

# %%
# !git pull
# Out:
# Already up to date.
