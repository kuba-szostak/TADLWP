# %%
# !git clone https://github.com/kuba-szostak/TADLWP
# Out:
# Cloning into 'TADLWP'...
# remote: Enumerating objects: 78, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (61/61), done.
# remote: Total 78 (delta 9), reused 78 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (78/78), 1.38 MiB | 20.52 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
# %ls
# Out:
# pycharm-libs/  sample_data/  TADLWP/

# %%
# %cd TADLWP
# Out:
# /content/TADLWP

# %%
# %cd Lab6_student/student/code
# Out:
# /content/TADLWP/Lab6_student/student/code

# %%
import part_1 as p1
p1.main()
# Out:
# Loading CIFAR-10 dataset...
# 100%|██████████| 170M/170M [00:03<00:00, 49.0MB/s]
# Dataset loaded
# GPU available: Tesla T4
# Epoch 1/8 - Train Loss: 2.3047, Train Acc: 0.0920 - Val Loss: 2.3040, Val Acc: 0.1162
# Epoch 2/8 - Train Loss: 2.3019, Train Acc: 0.1160 - Val Loss: 2.3039, Val Acc: 0.0978
# Epoch 3/8 - Train Loss: 2.2989, Train Acc: 0.1140 - Val Loss: 2.3039, Val Acc: 0.0978
# Epoch 4/8 - Train Loss: 2.2970, Train Acc: 0.1140 - Val Loss: 2.3044, Val Acc: 0.0978
# Epoch 5/8 - Train Loss: 2.2953, Train Acc: 0.1140 - Val Loss: 2.3049, Val Acc: 0.0988
# Epoch 6/8 - Train Loss: 2.2940, Train Acc: 0.1160 - Val Loss: 2.3050, Val Acc: 0.1048
# Epoch 7/8 - Train Loss: 2.2928, Train Acc: 0.1160 - Val Loss: 2.3054, Val Acc: 0.1010
# Epoch 8/8 - Train Loss: 2.2916, Train Acc: 0.1210 - Val Loss: 2.3049, Val Acc: 0.1048
# ...
# FX GRAPH NODES
# ...
# name=x                    op=placeholder     target=x
# name=net_0_net_0          op=call_module     target=net.0.net.0
# ...
